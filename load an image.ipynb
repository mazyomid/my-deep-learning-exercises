# %%
import matplotlib.pyplot as plt

# %%
data=plt.imread('download.jfif')
data1=plt.imread('download.jfif')

# %%
plt.imshow(data)

# %%
data[:,:,1]=0
data[:,:,2]=0
plt.imshow(data)

# %%
data[0:100,0:100,:]=1

plt.imshow(data)

# %%
import numpy as np
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114]).astype(int)
x=rgb2gray(data1)
plt.imshow(x,cmap='Greys')

# %%
x.shape
# Out:
# (199, 254)
